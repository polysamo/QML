# %% [markdown]
# # Guia da Camada de Transporte
# ### IMPORTANDO AS DEPENDÊNCIAS
# ##### O documento tem o objetivo de demostrar o funcionamento da camada de transporte, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ##### Instanciando a rede, e setando a topologia.

# %%
rede = Network()
rede.set_ready_topology('grade',8,3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Definindo os hosts alice e bob nos nós 1 e 2 respectivamente.

# %%
alice = rede.get_host(0)
bob = rede.get_host(8)

# %% [markdown]
# ##### Verificação da memória de Alice e Bob.

# %%
print('memoria de alice:',(alice.memory))
print('memoria de bob:',(bob.memory))
# Out:
# memoria de alice: []
# memoria de bob: []

# %% [markdown]
# ##### A função a seguir é chamada para que seja realizada a requesição de uma rota para que haja a transmissão de n qubits necessários. Ela vai executar toda a camada de transporte.

# %%
# rede.transportlayer.run_transport_layer(0,8,11)
rede.transportlayer.run_transport_layer_eprs(0,8,10)
# Out:
# 2025-01-12 16:38:50,404: Qubit 0 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,406: Qubit 0 criado com fidelidade inicial 0.9541691066141038 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,407: Qubit 1 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,408: Qubit 1 criado com fidelidade inicial 0.9999283200751694 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,409: Qubit 2 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,410: Qubit 2 criado com fidelidade inicial 0.9967675791016297 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,411: Qubit 3 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,412: Qubit 3 criado com fidelidade inicial 0.9899987245543981 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,412: Qubit 4 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,413: Qubit 4 criado com fidelidade inicial 0.9991430193941157 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,413: Qubit 5 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,415: Qubit 5 criado com fidelidade inicial 0.9822259822246358 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,415: Qubit 6 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,416: Qubit 6 criado com fidelidade inicial 0.99799633540976 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,417: Qubit 7 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,419: Qubit 7 criado com fidelidade inicial 0.9733807763667932 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,420: Qubit 8 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,420: Qubit 8 criado com fidelidade inicial 0.9894522826286787 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,421: Qubit 9 adicionado à memória do Host 0.
# 2025-01-12 16:38:50,422: Qubit 9 criado com fidelidade inicial 0.9637646371187842 e adicionado à memória do Host 0.
# 2025-01-12 16:38:50,423: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2025-01-12 16:38:50,425: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF38F4DE50> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,426: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5ACD4110> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,426: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5ACE28D0> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,427: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AC99350> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,427: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5ACDBB10> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,428: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD1B750> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,428: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD1BD90> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,429: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5ACE3050> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,429: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF38F60B50> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,430: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF38A9A4D0> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,430: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5ACDA050> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,431: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD20690> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,432: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD20790> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,433: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD216D0> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,433: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD219D0> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,434: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD21550> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,434: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5ACE2650> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,434: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD21310> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,435: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD1B010> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,436: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD1B2D0> adicionado ao canal (0, 3).
# 2025-01-12 16:38:50,437: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD22390> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,438: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD21610> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,438: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD1B9D0> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,439: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD22A90> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,439: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD1BE10> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,439: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD22890> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,440: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5A802550> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,440: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD1BF90> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,441: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD223D0> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,442: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD22310> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,442: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AC0FB10> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,443: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AC8C810> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,443: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD23A10> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,445: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD23810> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,445: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AD23410> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,446: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AC0FC90> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,446: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AC85190> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,447: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5ACBD650> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,447: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5AC2D3D0> adicionado ao canal (3, 6).
# 2025-01-12 16:38:50,449: Par EPR <quantumnet.objects.epr.Epr object at 0x000001CF5A
Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9684910757595272
# 2025-01-12 16:38:50,540: Fidelidade atual da rota: 0.9684910757595272
# 2025-01-12 16:38:50,541: Fidelidade final: 0.9685 (F_qubit: 0.9279 * F_rota: 0.9685)
# 2025-01-12 16:38:50,542: Fidelidade do EPR 0->3: 0.9910359161258742
# 2025-01-12 16:38:50,542: Fidelidade do EPR 3->6: 0.9910359161258742
# 2025-01-12 16:38:50,545: Fidelidade do EPR 6->7: 0.9910359161258742
# 2025-01-12 16:38:50,546: Fidelidade do EPR 7->8: 0.9910359161258742
# 2025-01-12 16:38:50,547: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9646229185299477
# 2025-01-12 16:38:50,547: Fidelidade atual da rota: 0.9646229185299477
# 2025-01-12 16:38:50,548: Fidelidade final: 0.9646 (F_qubit: 0.8913 * F_rota: 0.9646)
# 2025-01-12 16:38:50,548: Foram utilizados 40 pares EPRs ao longo da transmissão.
# 2025-01-12 16:38:50,548: Transmissão de 10 qubits entre 0 e 8 concluída com sucesso.
# True

# %%
rede.get_total_useds_eprs()
# Out:
# 2025-01-12 16:38:50,565: Eprs usados na camada LinkLayer: 0
# 2025-01-12 16:38:50,567: Eprs usados na camada NetworkLayer: 0
# 2025-01-12 16:38:50,569: Eprs usados na camada ApplicationLayer: 40
# 40

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada de Transporte.

# %%
rede.get_total_useds_qubits()
# Out:
# 2025-01-12 16:38:50,586: Qubits usados na camada PhysicalLayer: 10
# 2025-01-12 16:38:50,588: Qubits usados na camada LinkLayer: 0
# 2025-01-12 16:38:50,589: Qubits usados na camada TransportLayer: 0
# 2025-01-12 16:38:50,590: Qubits usados na camada ApplicationLayer: 0
# 10

# %% [markdown]
# ##### Essa função apresenta uma lista de métricas do transmissão dos qubits.

# %%
rede.transportlayer.get_teleported_qubits()
# Out:
# []

# %% [markdown]
# ##### No avg_fidelity_on_ltransportlayer, é realizada o cálculo da média da fidelidade dos ERPs criados na camada de Transporte.

# %%
rede.transportlayer.avg_fidelity_on_transportlayer()
# Out:
# 2025-01-12 16:38:50,669: Nenhum qubit foi utilizado na camada de transporte.
# 0.0

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 10

# %% [markdown]
# ##### Por meio do display_all_qubits_timeslot, pode-se verificar em qual timeslot cada qubit foi criado.

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 0
# Qubit 1 foi criado no timeslot 0
# Qubit 2 foi criado no timeslot 0
# Qubit 3 foi criado no timeslot 0
# Qubit 4 foi criado no timeslot 0
# Qubit 5 foi criado no timeslot 0
# Qubit 6 foi criado no timeslot 0
# Qubit 7 foi criado no timeslot 0
# Qubit 8 foi criado no timeslot 0
# Qubit 9 foi criado no timeslot 0
